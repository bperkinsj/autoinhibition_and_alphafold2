# %% [markdown]
# This notebook is for adjusting the files to give to Jen for a few PCA plots.

# %%
from pdbecif.mmcif_io import CifFileReader, CifFileWriter
from biopandas.pdb import PandasPdb
import pandas as pd
import numpy as np
import project_pipeline.scripts.utils as utils
import os

# %%
def assert_equal_size(gt_trim_df, pred_trim_df):
    try:
        assert len(pred_trim_df) == len(gt_trim_df)
        return True
    except AssertionError:
        gt_sim = gt_trim_df.drop(['id', 'Cartn_x', 'Cartn_y', 'Cartn_z', 'occupancy', 'B_iso_or_equiv', 'type_symbol', 'pdbx_formal_charge'], axis=1)
        pred_sim = pred_trim_df.drop(['id', 'Cartn_x', 'Cartn_y', 'Cartn_z', 'occupancy', 'B_iso_or_equiv', 'type_symbol', 'pdbx_formal_charge'], axis=1)
        diff = pd.concat([gt_sim, pred_sim]).drop_duplicates(keep=False)
        diff.to_csv('./project_pipeline/data/AssertionError.tsv', sep='\t')
        print(diff)
        print('AssertionError! Check file')
        return False

def drop_unshared_atoms(pdb1, pdb2):

    present_atoms = []

    # Define atom_names for hydrogens
    hydrogens = ['HA', 'HB1', 'HB2', 'HB3', 'H', 'HA2', 'HA3', 'HG2', 'HG3', 'HD2', 'HD3', 'HE1', 'HE2',
                'HE3', 'HB', 'HG11', 'HG12', 'HG13', 'HG21', 'HG22', 'HG23', 'HE', 'HH11', 'HH12', 'HH21',
                'HH22', 'HE21', 'HE22', 'HD1', 'HZ', 'HH', 'HG1', 'HD21', 'HD22', 'HG', 'HD11', 'HD12', 
                'HD13', 'HD23', 'HZ1', 'HZ2', 'HZ3', 'HH2']
    # Define possible alternate conformations
    alt_locations = ['B', 'C', 'D', 'E']

    pdb1 = pdb1[(~pdb1['label_atom_id'].isin(hydrogens)) & (~pdb1['label_alt_id'].isin(alt_locations)) & (pdb1['pdbx_PDB_model_num'] == '1')].reset_index(drop=True)

    pdb2 = pdb2[(~pdb2['label_atom_id'].isin(hydrogens)) & (~pdb2['label_alt_id'].isin(alt_locations)) & (pdb2['pdbx_PDB_model_num'] == '1')].reset_index(drop=True)

    pdb1_sub = pdb1[['label_atom_id', 'label_comp_id', 'label_seq_id']]
    pdb2_sub = pdb2[['label_atom_id', 'label_comp_id', 'label_seq_id']]
    pdb_shared = pd.merge(pdb1_sub, pdb2_sub, on=['label_atom_id', 'label_comp_id', 'label_seq_id'], how='inner')

    pdb1_trim = pd.merge(pdb1, pdb_shared, on=['label_atom_id', 'label_comp_id', 'label_seq_id'], how='inner')
    pdb2_trim = pd.merge(pdb2, pdb_shared, on=['label_atom_id', 'label_comp_id', 'label_seq_id'], how='inner')

    return pdb1_trim, pdb2_trim

def trim_pdbs(df, gt_path_in, trim_path_out):

    uniprots = df['uniprot'].unique()

    for uniprot in uniprots:

        # Make sure the uniprot directory exists
        utils.uniprot_dirs(trim_path_out, uniprot=uniprot)

        # Read in the files
        print(f'Trying {uniprot}...')
        
        df_prot = df[df['uniprot'] == uniprot].reset_index(drop=True)
        pdbs = df_prot['pdb'].unique()

        # Loop through the pdbs, get the atoms for each, and then find the common atoms between all of them
        pdb_ids = []
        pdb_dfs = []
        pdb_objs = []

        for pdb in pdbs:

            chain1 = df_prot[df_prot['pdb'] == pdb]['chain'].unique()[0]
            pdb_fn = f'{pdb}.cif'
            uniprot_path = f'{uniprot}/'

            # Generate file paths using format templates
            pdb_fp = os.path.join(gt_path_in, uniprot_path, pdb_fn)

            # Initiate reader object
            cfr = CifFileReader()

            # Create dataframe with gt atoms in desired chain
            pdb_obj = cfr.read(pdb_fp, output='cif_dictionary', ignore=['_struct_conn'])
            pdb_all_chains = pd.DataFrame.from_dict(pdb_obj[pdb.upper()]['_atom_site'])
            pdbc = pdb_all_chains[pdb_all_chains['label_asym_id'] == chain1].reset_index(drop=True)

            pdb_dfs.append(pdbc)
            pdb_ids.append(pdb)
            pdb_objs.append(pdb_obj)
        
        # Find common atoms between files
        print(f'Comparing files for {uniprot}...')

        print([len(d) for d in pdb_dfs])
        print(pdb_ids)

        # Trim the files to only common atoms
        common_df = pdb_dfs[0][['label_atom_id', 'label_comp_id', 'label_seq_id']]

        for idx, pdb_df in enumerate(pdb_dfs[1:], start=1):
            common_df = pd.merge(common_df, pdb_df[['label_atom_id', 'label_comp_id', 'label_seq_id']], 
                                 on=['label_atom_id', 'label_comp_id', 'label_seq_id'], how='inner').reset_index(drop=True)
            print(len(common_df))
            print(idx)
            print(pdb_ids[idx])
            
        pdb_dfs = [pd.merge(pdb, common_df, on=['label_atom_id', 'label_comp_id', 'label_seq_id'], how='inner').reset_index(drop=True) for pdb in pdb_dfs]

        if len(set([len(pdb_df) for pdb_df in pdb_dfs])) != 1:
            print('Lengths of pdb_dfs are not equal')
            break
            
        else:
            print(f'Lengths of pdb_dfs are equal and have {len(pdb_dfs[0])} atoms')
            for i in range(len(pdb_dfs)):

                pdb_id = pdb_ids[i]
                pdb_df = pdb_dfs[i]
                pdb_obj = pdb_objs[i]

                # Convert back to mmCIF-like dictionary
                pdb_dict = pdb_df.to_dict(orient='list')
                pdb_obj[pdb_id.upper()]['_atom_site'] = pdb_dict
                
                pdb_fn = f'{pdb_id}.cif'
                trim_fp_out = os.path.join(trim_path_out, uniprot_path, pdb_fn)

                CifFileWriter(trim_fp_out).write(pdb_obj)

def trim_cf_pdb(df, gt_path_in, pred_path_in, pred_path_out, 
              gt_format='{uniprot}/{pdb}.cif', pred_format='{uniprot}/{filename}'):

    for i in range(len(df)):
        
        # Define parameters for selecting files
        uniprot = df.loc[i, 'uniprot']
        pdb = df.loc[i, 'pdb']
        cluster = df.loc[i, 'cluster']
        filename = df.loc[i, 'cf_filename']
        chain = df.loc[i, 'chain']

# Generate file paths using format templates
        gt_fn = os.path.join(gt_path_in, gt_format.format(uniprot=uniprot, pdb=pdb))
        pred_fn = os.path.join(pred_path_in, pred_format.format(uniprot=uniprot, filename=filename))
        pred_fn_out = os.path.join(pred_path_out, f'{uniprot}/{uniprot}_{cluster}.pdb')

        # Make sure the uniprot directory exists
        utils.uniprot_dirs(pred_path_out, uniprot=uniprot)

        print(f'Trying {pdb} - {cluster} for {uniprot}...')

        # Have to convert pdb column names to cif column names
        mapper = {'record_name': 'group_PDB',
                    'atom_number': 'id',
                    'element_symbol': 'type_symbol',
                    'atom_name': 'label_atom_id',
                    'alc_loc': 'label_alt_id',
                    'residue_name': 'label_comp_id',
                    'chain_id': 'label_asym_id', 
                    'residue_number': 'label_seq_id',
                    'x_coord': 'Cartn_x', 
                    'y_coord': 'Cartn_y', 
                    'z_coord': 'Cartn_z',
                    'occupancy': 'occupancy',
                    'b_factor': 'B_iso_or_equiv',
                    'charge': 'pdbx_formal_charge'}
        
        reverse_mapper = {v: k for k, v in mapper.items()}

        # Initiate reader objects
        cfr = CifFileReader()
        ppdb = PandasPdb()

        # Create dataframe with gt atoms in desired chain
        gt_obj = cfr.read(gt_fn, output='cif_dictionary', ignore=['_struct_conn'])
        gt_all_chains = pd.DataFrame.from_dict(gt_obj[pdb.upper()]['_atom_site'])
        gt = gt_all_chains[gt_all_chains['label_asym_id'] == chain].reset_index(drop=True)

        # Create dataframe with pred atoms. ColabFold files are only in pdb format
        pred_obj = ppdb.read_pdb(pred_fn)
        pred = pred_obj.df['ATOM']
        pred = pred.rename(columns=mapper)
        # Must convert all columns to string
        all_columns = list(pred.columns)
        pred[all_columns] = pred[all_columns].astype(str)

        print('Length of gt: ' + str(len(gt)) + ', Length of pred:' + str(len(pred)))

        # Find common atoms between files
        print(f'Comparing files for {pdb} - {cluster}...')
        atoms_pred, extra_atoms_gt = utils.compare_atoms(gt, pred)

        # Trim the files
        gt_trim, pred_trim = utils.drop_unshared_atoms(gt, pred, atoms_pred, extra_atoms_gt)

        print('Length of gt_trim: ' + str(len(gt_trim)) + ', Length of pred_trim: ' + str(len(pred_trim)))
    

        # Don't need to convert to dictionary, can just pass back as df
        pred_trim = pred_trim.rename(columns=reverse_mapper)
        # Convert column types back to original
        pred_trim[['atom_number', 'residue_number', 'line_idx']] = pred_trim[['atom_number', 'residue_number', 'line_idx']].astype(int)
        pred_trim[['x_coord', 'y_coord', 'z_coord', 'occupancy', 'b_factor', 'charge']] = pred_trim[['x_coord', 
                                                                                                    'y_coord', 
                                                                                                    'z_coord', 
                                                                                                    'occupancy', 
                                                                                                    'b_factor',
                                                                                                    'charge']].astype(float)
        pred_obj.df['ATOM'] = pred_trim

        # Check whether the trimmed files are the same length
        assertion = utils.assert_equal_size(gt_trim, pred_trim)

        if assertion == True:
            print('Trimmed files are the same length')
        else:
            break
        
        if len(gt_trim) == 0:
            print(f'No common atoms found for {pdb}. Removing from dataframe...')
        else:
            print(f'Success! Creating trimmed files for {pdb} - {cluster}...')
            # Write trimmed files
            pred_obj.to_pdb(path=pred_fn_out, records=None)

def trim_cifs(df, gt_path_in, gt_path_out, pred_path_in, pred_path_out):

    trim_values = []
    for i in range(len(df)):
        
        # Define parameters for selecting files
        uniprot = df.loc[i, 'uniprot']
        pdb = df.loc[i, 'pdb']
        chain = df.loc[i, 'chain']
        gt_fn = df.loc[i, 'gt_fn']
        uniprot_path = f'{uniprot}/'
        pred_fn = df.loc[i, 'af_filename']

        # Generate file paths using format templates
        gt_fp = os.path.join(gt_path_in, uniprot_path, gt_fn)
        gt_fp_out = os.path.join(gt_path_out, uniprot_path, gt_fn)
        pred_fp = os.path.join(pred_path_in, pred_fn)
        pred_fp_out = os.path.join(pred_path_out, uniprot_path, f'{uniprot}_full_depth.cif')

        # Make sure the uniprot directory exists
        utils.uniprot_dirs(gt_path_out, pred_path_out, uniprot=uniprot)
            
        print(f'Trying {pdb} for {uniprot}...')

        # Initiate reader object
        cfr = CifFileReader()

        # Create dataframe with gt atoms in desired chain
        gt_obj = cfr.read(gt_fp, output='cif_dictionary', ignore=['_struct_conn'])
        gt_all_chains = pd.DataFrame.from_dict(gt_obj[pdb.upper()]['_atom_site'])
        gt = gt_all_chains[gt_all_chains['label_asym_id'] == chain].reset_index(drop=True)

        # Create dataframe with pred atoms (pred file only contains our desired chain)
        pred_obj = cfr.read(pred_fp, output='cif_dictionary')
        pred = pd.DataFrame.from_dict(pred_obj[f'AF-{uniprot}-F1']['_atom_site'])

        print('Length of gt: ' + str(len(gt)) + ', Length of pred:' + str(len(pred)))

        # Find common atoms between files
        print(f'Comparing files for {pdb}...')
        atoms_pred, extra_atoms_gt = utils.compare_atoms(gt, pred)

        # Trim the files
        gt_trim, pred_trim = utils.drop_unshared_atoms(gt, pred, atoms_pred, extra_atoms_gt)

        print('Length of gt_trim: ' + str(len(gt_trim)) + ', Length of pred_trim: ' + str(len(pred_trim)))
        
        # Convert back to mmCIF-like dictionary
        gt_dict = gt_trim.to_dict(orient='list')
        gt_obj[pdb.upper()]['_atom_site'] = gt_dict

        pred_dict = pred_trim.to_dict(orient='list')
        pred_obj[f'AF-{uniprot}-F1']['_atom_site'] = pred_dict

        # Check whether the trimmed files are the same length
        assertion = utils.assert_equal_size(gt_trim, pred_trim)

        if assertion == True:
            print('Trimmed files are the same length')
        else:
            break
        
        if len(gt_trim) == 0:
            print(f'No common atoms found for {pdb}. Removing from dataframe...')
        else:
            print(f'Success! Creating trimmed files for {pdb}...')
            # Write trimmed files
            CifFileWriter(gt_fp_out).write(gt_obj)
            CifFileWriter(pred_fp_out).write(pred_obj)


        # Compile some information on the trimmed files
        trim_values_dict = utils.trim_stats(uniprot, pdb, gt, gt_trim, pred, pred_trim)
        trim_values.append(trim_values_dict)
    
    # Add trim values to dataframe
    df_trim = pd.DataFrame(trim_values)
    df = df.merge(df_trim, on = ['pdb', 'uniprot'])

    # Drop any files that have no common atoms.
    df = df[df['gt_trim_len'] != 0].reset_index(drop=True)


    return trim_values, df

# %%
# Our proteins of interest
prots = ['P35520']

# directories
gt_in_path = './project_pipeline/data/input/RCSB_cif_best/'
pred_in_path = './project_pipeline/data/input/Colabfold_cif/autoinhibited/'
fd_in_path = './project_pipeline/data/input/Alphafold_cif/'
trim_path = './project_pipeline/data/output/jen_pca/'

# %%
# Determine the structures with the maximum 2_comp difference between them for our proteins of interest
df = pd.read_csv('./project_pipeline/data/classified_files.tsv', sep='\t')
df2 = pd.read_csv('./project_pipeline/data/ai_pdb_clusters.tsv', sep='\t')

# Create a dataframe to work from
difs = df[df['uniprot'].isin(prots)].reset_index(drop=True)
# difs = difs[(difs['percent_region_1'] >= 99) & (difs['percent_region_2'] >= 99)] # Select only the best structures

# Trim the two experimental files
trim_pdbs(difs, gt_in_path, trim_path)

# Trim the predicted files to match only the first trimmed experimental file for each protein
for prot in prots:
    pdb1 = difs[difs['uniprot'] == prot]['pdb'].unique()[0]
    colabfold_df = df2[df2['pdb'] == pdb1].reset_index(drop=True)
    af_df = colabfold_df[['uniprot', 'pdb', 'af_filename', 'chain']].drop_duplicates().reset_index(drop=True)
    af_df['gt_fn'] = af_df['pdb'] + '.cif'

    trim_values, df = trim_cifs(af_df, trim_path, trim_path, fd_in_path, trim_path)

    trim_cf_pdb(colabfold_df, trim_path, pred_in_path, trim_path,
                                        gt_format = '{uniprot}/{pdb}.cif', pred_format = '{uniprot}/{filename}')
# Out:
# Trying P35520...
# Comparing files for P35520...
# [3626, 3631, 3795, 3557, 3689, 3921, 3921, 3921, 3921]
# ['4coo', '4l0d', '4l28', '4pcu', '7qgt', '8s5h', '8s5i', '8s5j', '8s5k']
# 3593
# 1
# 4l0d
# 3581
# 2
# 4l28
# 3524
# 3
# 4pcu
# 3524
# 4
# 7qgt
# 3515
# 5
# 8s5h
# 3515
# 6
# 8s5i
# 3515
# 7
# 8s5j
# 3515
# 8
# 8s5k
# Lengths of pdb_dfs are equal and have 3515 atoms
# Trying 4coo for P35520...
# Length of gt: 3515, Length of pred:4252
# Comparing files for 4coo...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo...
# Trying 4coo - 121 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 121...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 121...
# Trying 4coo - 229 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 229...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 229...
# Trying 4coo - 128 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 128...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 128...
# Trying 4coo - 180 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 180...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 180...
# Trying 4coo - 036 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 036...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 036...
# Trying 4coo - 018 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 018...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 018...
# Trying 4coo - 060 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 060...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 060...
# Trying 4coo - 189 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 189...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 189...
# Trying 4coo - 050 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 050...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 050...
# Trying 4coo - 096 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 096...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 096...
# Trying 4coo - 138 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 138...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 138...
# Trying 4coo - 049 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 049...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 049...
# Trying 4coo - 216 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 216...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 216...
# Trying 4coo - U10-009 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-009...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-009...
# Trying 4coo - 159 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 159...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 159...
# Trying 4coo - 016 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 016...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 016...
# Trying 4coo - 134 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 134...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 134...
# Trying 4coo - 155 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 155...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 155...
# Trying 4coo - 106 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 106...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 106...
# Trying 4coo - 141 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 141...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 141...
# Trying 4coo - 187 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 187...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 187...
# Trying 4coo - 145 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 145...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 145...
# Trying 4coo - 133 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 133...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 133...
# Trying 4coo - 116 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 116...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 116...
# Trying 4coo - 190 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 190...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 190...
# Trying 4coo - 084 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 084...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 084...
# Trying 4coo - 081 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 081...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 081...
# Trying 4coo - 226 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 226...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 226...
# Trying 4coo - 002 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 002...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 002...
# Trying 4coo - 217 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 217...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 217...
# Trying 4coo - 001 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 001...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 001...
# Trying 4coo - 208 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 208...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 208...
# Trying 4coo - 220 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 220...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 220...
# Trying 4coo - 206 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 206...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 206...
# Trying 4coo - 193 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 193...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 193...
# Trying 4coo - 154 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 154...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 154...
# Trying 4coo - U10-003 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-003...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-003...
# Trying 4coo - 199 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 199...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 199...
# Trying 4coo - 149 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 149...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 149...
# Trying 4coo - 083 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 083...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 083...
# Trying 4coo - 212 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 212...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 212...
# Trying 4coo - 188 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 188...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 188...
# Trying 4coo - 022 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 022...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 022...
# Trying 4coo - 207 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 207...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 207...
# Trying 4coo - 015 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 015...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 015...
# Trying 4coo - 061 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 061...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 061...
# Trying 4coo - 007 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 007...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 007...
# Trying 4coo - 057 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 057...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 057...
# Trying 4coo - 137 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 137...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 137...
# Trying 4coo - 143 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 143...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 143...
# Trying 4coo - 178 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 178...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 178...
# Trying 4coo - 163 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 163...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 163...
# Trying 4coo - 055 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 055...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 055...
# Trying 4coo - 114 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 114...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 114...
# Trying 4coo - 091 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 091...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 091...
# Trying 4coo - 063 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 063...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 063...
# Trying 4coo - 094 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 094...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 094...
# Trying 4coo - 030 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 030...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 030...
# Trying 4coo - 078 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 078...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 078...
# Trying 4coo - 109 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 109...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 109...
# Trying 4coo - 196 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 196...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 196...
# Trying 4coo - 130 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 130...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 130...
# Trying 4coo - 013 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 013...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 013...
# Trying 4coo - 195 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 195...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 195...
# Trying 4coo - U100-006 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-006...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-006...
# Trying 4coo - 088 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 088...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 088...
# Trying 4coo - 046 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 046...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 046...
# Trying 4coo - U100-001 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-001...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-001...
# Trying 4coo - 037 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 037...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 037...
# Trying 4coo - 093 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 093...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 093...
# Trying 4coo - U100-008 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-008...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-008...
# Trying 4coo - 053 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 053...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 053...
# Trying 4coo - U100-003 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-003...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-003...
# Trying 4coo - 171 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 171...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 171...
# Trying 4coo - 118 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 118...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 118...
# Trying 4coo - 105 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 105...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 105...
# Trying 4coo - 089 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 089...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 089...
# Trying 4coo - 072 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 072...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 072...
# Trying 4coo - 064 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 064...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 064...
# Trying 4coo - 028 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 028...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 028...
# Trying 4coo - 157 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 157...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 157...
# Trying 4coo - 080 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 080...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 080...
# Trying 4coo - 122 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 122...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 122...
# Trying 4coo - 151 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 151...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 151...
# Trying 4coo - 153 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 153...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 153...
# Trying 4coo - 227 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 227...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 227...
# Trying 4coo - 020 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 020...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 020...
# Trying 4coo - 127 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 127...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 127...
# Trying 4coo - 150 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 150...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 150...
# Trying 4coo - U10-006 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-006...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-006...
# Trying 4coo - 169 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 169...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 169...
# Trying 4coo - 073 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 073...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 073...
# Trying 4coo - 044 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 044...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 044...
# Trying 4coo - 070 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 070...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 070...
# Trying 4coo - 025 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 025...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 025...
# Trying 4coo - 008 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 008...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 008...
# Trying 4coo - 077 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 077...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 077...
# Trying 4coo - 221 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 221...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 221...
# Trying 4coo - 184 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 184...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 184...
# Trying 4coo - 198 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 198...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 198...
# Trying 4coo - 228 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 228...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 228...
# Trying 4coo - 115 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 115...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 115...
# Trying 4coo - 062 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 062...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 062...
# Trying 4coo - 181 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 181...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 181...
# Trying 4coo - 119 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 119...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 119...
# Trying 4coo - 192 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 192...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 192...
# Trying 4coo - 012 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 012...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 012...
# Trying 4coo - 068 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 068...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 068...
# Trying 4coo - 234 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 234...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 234...
# Trying 4coo - 235 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 235...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 235...
# Trying 4coo - 175 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 175...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 175...
# Trying 4coo - 222 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 222...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 222...
# Trying 4coo - 225 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 225...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 225...
# Trying 4coo - 085 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 085...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 085...
# Trying 4coo - 011 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 011...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 011...
# Trying 4coo - 067 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 067...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 067...
# Trying 4coo - 069 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 069...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 069...
# Trying 4coo - U100-009 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-009...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-009...
# Trying 4coo - 107 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 107...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 107...
# Trying 4coo - 223 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 223...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 223...
# Trying 4coo - 120 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 120...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 120...
# Trying 4coo - 006 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 006...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 006...
# Trying 4coo - 108 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 108...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 108...
# Trying 4coo - U10-001 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-001...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-001...
# Trying 4coo - 142 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 142...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 142...
# Trying 4coo - 186 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 186...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 186...
# Trying 4coo - 152 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 152...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 152...
# Trying 4coo - U100-002 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-002...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-002...
# Trying 4coo - 017 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 017...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 017...
# Trying 4coo - 194 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 194...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 194...
# Trying 4coo - 071 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 071...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 071...
# Trying 4coo - 210 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 210...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 210...
# Trying 4coo - 176 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 176...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 176...
# Trying 4coo - U100-007 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-007...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-007...
# Trying 4coo - 170 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 170...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 170...
# Trying 4coo - 004 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 004...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 004...
# Trying 4coo - 124 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 124...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 124...
# Trying 4coo - 146 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 146...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 146...
# Trying 4coo - 041 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 041...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 041...
# Trying 4coo - 148 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 148...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 148...
# Trying 4coo - 076 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 076...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 076...
# Trying 4coo - 185 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 185...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 185...
# Trying 4coo - 040 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 040...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 040...
# Trying 4coo - 101 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 101...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 101...
# Trying 4coo - 042 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 042...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 042...
# Trying 4coo - 054 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 054...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 054...
# Trying 4coo - 009 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 009...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 009...
# Trying 4coo - 045 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 045...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 045...
# Trying 4coo - 095 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 095...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 095...
# Trying 4coo - 117 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 117...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 117...
# Trying 4coo - 213 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 213...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 213...
# Trying 4coo - 033 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 033...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 033...
# Trying 4coo - 024 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 024...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 024...
# Trying 4coo - 104 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 104...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 104...
# Trying 4coo - 087 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 087...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 087...
# Trying 4coo - 168 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 168...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 168...
# Trying 4coo - 092 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 092...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 092...
# Trying 4coo - 021 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 021...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 021...
# Trying 4coo - 139 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 139...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 139...
# Trying 4coo - 136 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 136...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 136...
# Trying 4coo - 082 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 082...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 082...
# Trying 4coo - 215 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 215...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 215...
# Trying 4coo - 097 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 097...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 097...
# Trying 4coo - 100 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 100...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 100...
# Trying 4coo - 112 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 112...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 112...
# Trying 4coo - 160 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 160...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 160...
# Trying 4coo - 032 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 032...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 032...
# Trying 4coo - 035 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 035...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 035...
# Trying 4coo - 014 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 014...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 014...
# Trying 4coo - U10-004 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-004...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-004...
# Trying 4coo - 065 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 065...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 065...
# Trying 4coo - 102 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 102...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 102...
# Trying 4coo - 000 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 000...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 000...
# Trying 4coo - 090 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 090...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 090...
# Trying 4coo - 161 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 161...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 161...
# Trying 4coo - 023 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 023...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 023...
# Trying 4coo - 162 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 162...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 162...
# Trying 4coo - 132 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 132...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 132...
# Trying 4coo - 126 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 126...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 126...
# Trying 4coo - 172 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 172...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 172...
# Trying 4coo - 019 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 019...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 019...
# Trying 4coo - 158 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 158...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 158...
# Trying 4coo - 211 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 211...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 211...
# Trying 4coo - 098 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 098...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 098...
# Trying 4coo - 191 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 191...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 191...
# Trying 4coo - 052 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 052...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 052...
# Trying 4coo - 200 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 200...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 200...
# Trying 4coo - 039 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 039...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 039...
# Trying 4coo - 232 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 232...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 232...
# Trying 4coo - 202 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 202...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 202...
# Trying 4coo - U10-000 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-000...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-000...
# Trying 4coo - U100-005 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-005...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-005...
# Trying 4coo - 140 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 140...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 140...
# Trying 4coo - U100-004 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-004...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-004...
# Trying 4coo - 209 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 209...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 209...
# Trying 4coo - 174 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 174...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 174...
# Trying 4coo - 179 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 179...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 179...
# Trying 4coo - U100-000 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U100-000...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U100-000...
# Trying 4coo - 165 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 165...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 165...
# Trying 4coo - 003 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 003...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 003...
# Trying 4coo - 043 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 043...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 043...
# Trying 4coo - 204 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 204...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 204...
# Trying 4coo - 074 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 074...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 074...
# Trying 4coo - 214 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 214...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 214...
# Trying 4coo - 203 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 203...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 203...
# Trying 4coo - 051 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 051...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 051...
# Trying 4coo - 005 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 005...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 005...
# Trying 4coo - 164 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 164...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 164...
# Trying 4coo - 086 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 086...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 086...
# Trying 4coo - 110 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 110...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 110...
# Trying 4coo - 075 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 075...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 075...
# Trying 4coo - 201 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 201...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 201...
# Trying 4coo - 167 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 167...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 167...
# Trying 4coo - 059 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 059...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 059...
# Trying 4coo - 144 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 144...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 144...
# Trying 4coo - 099 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 099...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 099...
# Trying 4coo - U10-005 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-005...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-005...
# Trying 4coo - 131 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 131...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 131...
# Trying 4coo - 058 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 058...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 058...
# Trying 4coo - 123 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 123...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 123...
# Trying 4coo - 056 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 056...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 056...
# Trying 4coo - 182 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 182...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 182...
# Trying 4coo - 205 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 205...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 205...
# Trying 4coo - 231 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 231...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 231...
# Trying 4coo - 147 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 147...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 147...
# Trying 4coo - 224 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 224...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 224...
# Trying 4coo - 183 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 183...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 183...
# Trying 4coo - 066 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 066...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 066...
# Trying 4coo - U10-008 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-008...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-008...
# Trying 4coo - 173 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 173...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 173...
# Trying 4coo - 111 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 111...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 111...
# Trying 4coo - 230 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 230...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 230...
# Trying 4coo - 010 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 010...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 010...
# Trying 4coo - 034 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 034...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 034...
# Trying 4coo - U10-002 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-002...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-002...
# Trying 4coo - 125 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 125...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 125...
# Trying 4coo - 166 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 166...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 166...
# Trying 4coo - 103 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 103...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 103...
# Trying 4coo - 026 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 026...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 026...
# Trying 4coo - 079 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 079...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 079...
# Trying 4coo - 029 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 029...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 029...
# Trying 4coo - 156 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 156...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 156...
# Trying 4coo - 129 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 129...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 129...
# Trying 4coo - 047 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 047...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 047...
# Trying 4coo - 177 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 177...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 177...
# Trying 4coo - 135 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 135...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 135...
# Trying 4coo - 218 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 218...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 218...
# Trying 4coo - 113 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 113...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 113...
# Trying 4coo - U10-007 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - U10-007...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - U10-007...
# Trying 4coo - 031 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 031...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 031...
# Trying 4coo - 197 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 197...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 197...
# Trying 4coo - 027 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 027...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 027...
# Trying 4coo - 048 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 048...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 048...
# Trying 4coo - 219 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 219...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 219...
# Trying 4coo - 233 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 233...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 233...
# Trying 4coo - 038 for P35520...
# Length of gt: 3515, Length of pred:4251
# Comparing files for 4coo - 038...
# Length of gt_trim: 3515, Length of pred_trim: 3515
# Trimmed files are the same length
# Success! Creating trimmed files for 4coo - 038...

# %%
# uniprot = 'P22681'

# df3 = pd.read_csv('./project_pipeline/data/ai_cluster_pae.tsv', sep='\t').rename(columns={'region_1': 'im', 'region_2': 'fd',
#                                                                                           'mean_pae_1_1': 'mean_pae_im_im', 'mean_pae_1_2': 'mean_pae_im_fd',
#                                                                                           'mean_pae_2_2': 'mean_pae_fd_fd'})
# df3 = df3[df3['uniprot'] == uniprot]
# df3.to_csv(f'../for_jen/{uniprot.lower()}_pae.csv', index=False)
